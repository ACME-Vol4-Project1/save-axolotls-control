# %%
import sympy as sy
import numpy as np
from scipy.integrate import solve_bvp
from matplotlib import pyplot as plt
from model import Model2

# %%
model = Model2(seasonal=False, const_u1=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model = Model2(seasonal=False, const_u1=0)
#
# File ~/save-axolotls-control/model.py:205, in Model2.__init__(self, seasonal, params, no_dead, const_u1)
#     202 self.sy_f_x = sy_f.jacobian(x).subs(self.params)    # get jacobians
#     203 self.sy_f_u = sy_f.jacobian(u).subs(self.params)
# --> 205 self._f_case1 = sy.lambdify(
#     206     args,
#     207     self.sy_f
#     208 )
#     210 self._f_x_case1 = sy.lambdify(
#     211     args,
#     212     self.sy_f_x
#     213 )
#     215 self._f_u_case1 = sy.lambdify(
#     216     args,
#     217     self.sy_f_u
#     218 )
#
# File ~/save-axolotls-control/.venv/lib/python3.12/site-packages/sympy/utilities/lambdify.py:894, in lambdify(args, expr, modules, printer, use_imps, dummify, cse, docstring_limit)
#     892 else:
# ...
