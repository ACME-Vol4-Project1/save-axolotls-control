# %%
import numpy as np
from model import Model

# %%
model = Model(seasonal=False, no_dead=True, const_u1=0.0)
display(model.sy_f)
# Out:
# Matrix([
# [-3.5e-5*I*S + 1.0*I*u2/(100*I + 5000) + 0.1*T1],
# [3.5e-5*I*S - 1.0*I*u2/(100*I + 5000) - 0.003*I],
# [                                       -0.1*T1]])

# %%
model = Model(seasonal=False, no_dead=True, const_u1=1)
display(model.sy_f)
# Out:
# Matrix([
# [-3.5e-5*I*S + 1.0*I*u2/(100*I + 5000) - 0.15*S*(1 - 2*T1/365) + 0.1*T1],
# [3.5e-5*I*S - 1.0*I*u2/(100*I + 5000) - 0.15*I*(1 - 2*T1/365) - 0.003*I],
# [                                 -0.1*T1 + 0.15*(1 - 2*T1/365)*(I + S)]])
